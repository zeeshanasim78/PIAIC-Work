# %%
import pandas as pd
import numpy as np

# %%
try:
    data = pd.read_csv("astronauts.csv")
    print("dataloaded")
except:
    print("File missing")
# Out:
# dataloaded

# %%
data.shape
# Out:
# (357, 19)

# %%
data.ndim
# Out:
# 2

# %%
data.head(1)
# Out:
#               Name    Year  Group  Status Birth Date    Birth Place Gender  \
# 0  Joseph M. Acaba  2004.0   19.0  Active  5/17/1967  Inglewood, CA   Male
#
#                                           Alma Mater Undergraduate Major  \
# 0  University of California-Santa Barbara; Univer...             Geology
#
#   Graduate Major Military Rank Military Branch  Space Flights  \
# 0        Geology           NaN             NaN              2
#
#    Space Flight (hr)  Space Walks  Space Walks (hr)  \
# 0               3307            2              13.0
#
#                                  Missions Death Date Death Mission
# 0  STS-119 (Discovery), ISS-31/32 (Soyuz)        NaN           NaN

# %%
data.tail(3)
# Out:
#                  Name    Year  Group   Status Birth Date        Birth Place  \
# 354  Alfred M. Worden  1966.0    5.0  Retired   2/7/1932        Jackson, MI
# 355     John W. Young  1962.0    2.0  Retired  9/24/1930  San Francisco, CA
# 356   George D. Zamka  1998.0   17.0  Retired  6/29/1962    Jersey City, NJ
#
#     Gender                                         Alma Mater  \
# 354   Male        US Military Academy; University of Michigan
# 355   Male                    Georgia Institute of Technology
# 356   Male  US Naval Academy; Florida Institute of Technology
#
#           Undergraduate Major                            Graduate Major  \
# 354          Military Science  Aeronautical & Astronautical Engineering
# 355  Aeronautical Engineering                                       NaN
# 356               Mathematics                    Engineering Management
#
#     Military Rank            Military Branch  Space Flights  \
# 354       Colonel     US Air Force (Retired)              1
# 355       Captain          US Navy (Retired)              6
# 356       Colonel  US Marine Corps (Retired)              2
#
#      Space Flight (hr)  Space Walks  Space Walks (hr)  \
# 354                295            1               0.5
# 355                835            3              20.0
# 356                692            0               0.0
#
#                                               Missions Death Date  \
# 354                                          Apollo 15        NaN
# 355  Gemini 3, Gemini 10, Apollo 10, Apollo 16, STS...        NaN
# 356            STS-120 (Discovery), STS-130 (Endeavor)        NaN
#
#     Death Mission
# 354           NaN
# 355           NaN
# 356           NaN

# %%
data.sample(10)
# Out:
#                     Name    Year  Group      Status  Birth Date  \
# 230     Leland D. Melvin  1998.0   17.0  Management   2/15/1964
# 169    Douglas G. Hurley  2000.0   18.0      Active  10/21/1966
# 352        David A. Wolf  1990.0   13.0     Retired   8/23/1956
# 320  William E. Thornton  1967.0    6.0     Retired   4/14/1929
# 76     Eileen M. Collins  1990.0   13.0     Retired  11/19/1959
# 222    William C. McCool  1996.0   16.0    Deceased   9/23/1961
# 162      Kathryn P. Hire  1995.0   15.0  Management   8/26/1959
# 21    Michael R. Barratt  2000.0   18.0      Active   4/16/1959
# 183       Scott J. Kelly  1996.0   16.0      Active   2/21/1964
# 155     Thomas J. Hennen     NaN    NaN     Retired   8/17/1952
#
#           Birth Place  Gender  \
# 230     Lynchburg, VA    Male
# 169      Endicott, NY    Male
# 352  Indianapolis, IN    Male
# 320        Faison, NC    Male
# 76         Elmira, NY  Female
# 222     San Diego, CA    Male
# 162        Mobile, AL  Female
# 21      Vancouver, WA    Male
# 183        Orange, NJ    Male
# 155        Albany, GA    Male
#
#                                             Alma Mater  \
# 230     University of Richmond; University of Virginia
# 169                                  Tulane University
# 352              Purdue University; Indiana University
# 320                       University of North Carolina
# 76   Syracuse University; Stanford University; Webs...
# 222  US Naval Academy; University of Maryland; US N...
# 162  US Naval Academy; Florida State Institute of T...
# 21   University of Washington; Northwestern Univers...
# 183  State University of New York Maritime College;...
# 155                                                NaN
#
#          Undergraduate Major                                 Graduate Major  \
# 230                Chemistry                  Materials Science Engineering
# 169        Civil Engineering                                            NaN
# 352   Electrical Engineering                                       Medicine
# 320                  Physics                                       Medicine
# 76   Mathematics & Economics  Operations Research; Space Systems Management
# 222           Naval Sciences     Computer Science; Aeronautical Engineering
# 162   Engineering Management                               Space Technology
# 21                   Zoology                   Medicine; Aerospace Medicine
# 183   Electrical Engineering                               Aviation Systems
# 155                      NaN                                            NaN
#
#              Military Rank         Military Branch  Space Flights  \
# 230                    NaN                     NaN              2
# 169                Colonel         US Marine Corps              2
# 352                    NaN                     NaN              3
# 320                    NaN                     NaN              2
# 76                 Colonel  US Air Force (Retired)              4
# 222              Commander                 US Navy              1
# 162                Captain       US Naval Reserves              2
# 21                     NaN                     NaN              2
# 183                Captain       US Navy (Retired)              4
# 155  Chief Warrant Officer       US Army (Retired)              1
#
#      Space Flight (hr)  Space Walks  Space Walks (hr)  \
# 230                565            0               0.0
# 169                683            0               0.0
# 352               4044            7              41.0
# 320                315            0               0.0
# 76                 890            0               0.0
# 222                382            0               0.0
# 162                711            0               0.0
# 21                5075            1               5.0
# 183              12490            3              18.0
# 155                166            0               0.0
#
#                                               Missions Death Date  \
# 230             STS-122 (Atlantis), STS-129 (Atlantis)        NaN
# 169             STS-127 (Endeavor), STS-135 (Atlantis)        NaN
# 352  STS-58 (Columbia). STS-86/89 (Atlantis/Endeavo...        NaN
# 320          STS-8 (Challenger), STS 51-B (Challenger)        NaN
# 76   STS-63 (Discovery), STS-84 (Atlantis), STS-114...        NaN
# 222                                 STS-107 (Columbia)   2/1/2003
# 162              STS-90 (Columbia), STS-130 (Endeavor)        NaN
# 21              ISS-19/20 (Soyuz), STS-133 (Discovery)        NaN
# 183  STS-103 (Discovery), STS-118 (Endeavor), ISS-2...        NaN
# 155                                  STS-44 (Atlantis)        NaN
#
#           Death Mission
# 230                 NaN
# 169                 NaN
# 352                 NaN
# 320                 NaN
# 76                  NaN
# 222  STS-107 (Columbia)
# 162                 NaN
# 21                  NaN
# 183                 NaN
# 155                 NaN

# %%
data.columns
# Out:
# Index(['Name', 'Year', 'Group', 'Status', 'Birth Date', 'Birth Place',
#        'Gender', 'Alma Mater', 'Undergraduate Major', 'Graduate Major',
#        'Military Rank', 'Military Branch', 'Space Flights',
#        'Space Flight (hr)', 'Space Walks', 'Space Walks (hr)', 'Missions',
#        'Death Date', 'Death Mission'],
#       dtype='object')

# %%
# changing column name

data.columns = [11,22,33,44,55,66,77,88,99,100,111,222,333,444,555,666,777,888,999]
data.columns = ['Name', 'Year', 'Group', 'Status', 'Birth Date', 'Birth Place',
       'Gender', 'Alma Mater', 'Undergraduate Major', 'Graduate Major',
       'Military Rank', 'Military Branch', 'Space Flights',
       'Space Flight (hr)', 'Space Walks', 'Space Walks (hr)', 'Missions',
       'Death Date', 'Death Mission']

# %%
data.head(1)
# Out:
#               Name    Year  Group  Status Birth Date    Birth Place Gender  \
# 0  Joseph M. Acaba  2004.0   19.0  Active  5/17/1967  Inglewood, CA   Male
#
#                                           Alma Mater Undergraduate Major  \
# 0  University of California-Santa Barbara; Univer...             Geology
#
#   Graduate Major Military Rank Military Branch  Space Flights  \
# 0        Geology           NaN             NaN              2
#
#    Space Flight (hr)  Space Walks  Space Walks (hr)  \
# 0               3307            2              13.0
#
#                                  Missions Death Date Death Mission
# 0  STS-119 (Discovery), ISS-31/32 (Soyuz)        NaN           NaN

# %%
data.rename(columns={'Birth Date':'birth_date', 'Birth Place':'birth_place',
                   'Alma Mater':'alma_mater', 'Undergraduate Major':'undergraduate_major', 'Graduate Major':'graduate_major',
       'Military Rank':'military_rank', 'Military Branch':'military_branch', 'Space Flights':'space_fights',
       'Space Flight (hr)':'space_flight(hr)', 'Space Walks':'space_walks', 'Space Walks (hr)':'space_walks(hr)',
       'Death Date':"death_date",'Space Walks (hr)':'space_walks(hr)', 'Death Mission':'death_mission' },inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 19 columns):
# Name                   357 non-null object
# Year                   331 non-null float64
# Group                  330 non-null float64
# Status                 357 non-null object
# birth_date             357 non-null object
# birth_place            357 non-null object
# Gender                 357 non-null object
# alma_mater             356 non-null object
# undergraduate_major    335 non-null object
# graduate_major         298 non-null object
# military_rank          207 non-null object
# military_branch        211 non-null object
# space_fights           357 non-null int64
# space_flight(hr)       357 non-null int64
# space_walks            357 non-null int64
# space_walks(hr)        357 non-null float64
# Missions               334 non-null object
# death_date             52 non-null object
# death_mission          16 non-null object
# dtypes: float64(3), int64(3), object(13)
# memory usage: 53.1+ KB

# %%
data.notnull().sum()
data.isnull().sum()
# Out:
# Name                     0
# Year                    26
# Group                   27
# Status                   0
# birth_date               0
# birth_place              0
# Gender                   0
# alma_mater               1
# undergraduate_major     22
# graduate_major          59
# military_rank          150
# military_branch        146
# space_fights             0
# space_flight(hr)         0
# space_walks              0
# space_walks(hr)          0
# Missions                23
# death_date             305
# death_mission          341
# dtype: int64

# %%
data.birth_date = pd.to_datetime(data.birth_date)

# %%
data.birth_date
# Out:
# 0     1967-05-17
# 1     1936-03-07
# 2     1946-03-03
# 3     1951-05-20
# 4     1930-01-20
#          ...
# 352   1956-08-23
# 353   1962-07-26
# 354   1932-02-07
# 355   1930-09-24
# 356   1962-06-29
# Name: birth_date, Length: 357, dtype: datetime64[ns]

# %%
data.death_date = pd.to_datetime(data.death_date)

# %%
data.head(1)
# Out:
#               Name    Year  Group  Status birth_date    birth_place Gender  \
# 0  Joseph M. Acaba  2004.0   19.0  Active 1967-05-17  Inglewood, CA   Male
#
#                                           alma_mater undergraduate_major  \
# 0  University of California-Santa Barbara; Univer...             Geology
#
#   graduate_major military_rank military_branch  space_fights  \
# 0        Geology           NaN             NaN             2
#
#    space_flight(hr)  space_walks  space_walks(hr)  \
# 0              3307            2             13.0
#
#                                  Missions death_date death_mission
# 0  STS-119 (Discovery), ISS-31/32 (Soyuz)        NaT           NaN

# %%
# we will deal you later 
#data.Year.astype('int32')
# data.Group.astype('int32')

# %%
data.Status.value_counts()
# Out:
# Retired       220
# Deceased       51
# Active         50
# Management     36
# Name: Status, dtype: int64

# %%
data.alma_mater.value_counts().sum()
# Out:
# 356

# %%
#data.alma_mater.unique()
data.alma_mater.nunique()
# Out:
# 280

# %%
pd.Series([11,2,np.nan, 33,33,55,6,55,np.nan]).unique()
# Out:
# array([11.,  2., nan, 33., 55.,  6.])

# %%
pd.Series([11,2,np.nan, 33,33,55,6,55,np.nan]).nunique()
# Out:
# 5

# %%
data.Year
# Out:
# 0      2004.0
# 1      1996.0
# 2      1984.0
# 3      1987.0
# 4      1963.0
#         ...
# 352    1990.0
# 353    1998.0
# 354    1966.0
# 355    1962.0
# 356    1998.0
# Name: Year, Length: 357, dtype: float64

# %%
data[data.Year.notnull()]
# Out:
#                       Name    Year  Group   Status birth_date  \
# 0          Joseph M. Acaba  2004.0   19.0   Active 1967-05-17
# 1           Loren W. Acton  1996.0    NaN  Retired 1936-03-07
# 2         James C. Adamson  1984.0   10.0  Retired 1946-03-03
# 3          Thomas D. Akers  1987.0   12.0  Retired 1951-05-20
# 4              Buzz Aldrin  1963.0    3.0  Retired 1930-01-20
# ..                     ...     ...    ...      ...        ...
# 352          David A. Wolf  1990.0   13.0  Retired 1956-08-23
# 353  Neil W. Woodward III   1998.0   17.0  Retired 1962-07-26
# 354       Alfred M. Worden  1966.0    5.0  Retired 1932-02-07
# 355          John W. Young  1962.0    2.0  Retired 1930-09-24
# 356        George D. Zamka  1998.0   17.0  Retired 1962-06-29
#
#            birth_place Gender  \
# 0        Inglewood, CA   Male
# 1         Lewiston, MT   Male
# 2           Warsaw, NY   Male
# 3        St. Louis, MO   Male
# 4        Montclair, NJ   Male
# ..                 ...    ...
# 352   Indianapolis, IN   Male
# 353        Chicago, IL   Male
# 354        Jackson, MI   Male
# 355  San Francisco, CA   Male
# 356    Jersey City, NJ   Male
#
#                                             alma_mater  \
# 0    University of California-Santa Barbara; Univer...
# 1     Montana State University; University of Colorado
# 2            US Military Academy; Princeton University
# 3                         University of Missouri-Rolla
# 4                             US Military Academy; MIT
# ..                                                 ...
# 352              Purdue University; Indiana University
# 353  MIT; University of Texas-Austin; George Washin...
# 354        US Military Academy; University of Michigan
# 355                    Georgia Institute of Technology
# 356  US Naval Academy; Florida Institute of Technology
#
#           undergraduate_major                            graduate_major  \
# 0                     Geology                                   Geology
# 1         Engineering Physics                             Solar Physics
# 2                 Engineering                     Aerospace Engineering
# 3         Applied Mathematics                       Applied Mathematics
# 4      Mechanical Engineering                              Astronautics
# ..                        ...                                       ...
# 352    Electrical Engineering                                  Medicine
# 353                   Physics              Physics; Business Management
# 354          Military Science  Aeronautical & Astronautical Engineering
# 355  Aeronautical Engineering                                       NaN
# 356               Mathematics                    Engineering Management
#
#     military_rank            military_branch  space_fights  space_flight(hr)  \
# 0             NaN                        NaN             2              3307
# 1             NaN                        NaN             1               190
# 2         Colonel          US Army (Retired)             2               334
# 3         Colonel     US Air Force (Retired)             4               814
# 4         Colonel     US Air Force (Retired)             2               289
# ..            ...                        ...           ...               ...
# 352           NaN                        NaN             3              4044
# 353     Commander                    US Navy             0                 0
# 354       Colonel     US Air Force (Retired)             1               295
# 355       Captain          US Navy (Retired)             6               835
# 356       Colonel  US Marine Corps (Retired)             2               692
#
#      space_walks  space_walks(hr)  \
# 0              2             13.0
# 1              0              0.0
# 2              0              0.0
# 3              4             29.0
# 4              2              8.0
# ..           ...              ...
# 352            7             41.0
# 353            0              0.0
# 354            1              0.5
# 355            3             20.0
# 356            0              0.0
#
#                                               Missions death_date  \
# 0               STS-119 (Discovery), ISS-31/32 (Soyuz)        NaT
# 1                                STS 51-F (Challenger)        NaT
# 2                 STS-28 (Columbia), STS-43 (Atlantis)        NaT
# 3    STS-41 (Discovery), STS-49 (Endeavor), STS-61 ...        NaT
# 4                                 Gemini 12, Apollo 11        NaT
# ..                                                 ...        ...
# 352  STS-58 (Columbia). STS-86/89 (Atlantis/Endeavo...        NaT
# 353                                                NaN        NaT
# 354                                          Apollo 15        NaT
# 355  Gemini 3, Gemini 10, Apollo 10, Apollo 16, STS...        NaT
# 356            STS-120 (Discovery), STS-130 (Endeavor)        NaT
#
#     death_mission
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ..            ...
# 352           NaN
# 353           NaN
# 354           NaN
# 355           NaN
# 356           NaN
#
# [331 rows x 19 columns]

# %% [markdown]
# # Handling Missing Values
#     - filling missing values
#     - dropping missing values

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 19 columns):
# Name                   357 non-null object
# Year                   331 non-null float64
# Group                  330 non-null float64
# Status                 357 non-null object
# birth_date             357 non-null datetime64[ns]
# birth_place            357 non-null object
# Gender                 357 non-null object
# alma_mater             356 non-null object
# undergraduate_major    335 non-null object
# graduate_major         298 non-null object
# military_rank          207 non-null object
# military_branch        211 non-null object
# space_fights           357 non-null int64
# space_flight(hr)       357 non-null int64
# space_walks            357 non-null int64
# space_walks(hr)        357 non-null float64
# Missions               334 non-null object
# death_date             52 non-null datetime64[ns]
# death_mission          16 non-null object
# dtypes: datetime64[ns](2), float64(3), int64(3), object(11)
# memory usage: 53.1+ KB

# %%
data.Year.isnull().sum()
# Out:
# 26

# %%
data.Year.fillna(data.Year.mode(),inplace=True)

# %%
data.Year
# Out:
# 0      2004.0
# 1      1996.0
# 2      1984.0
# 3      1987.0
# 4      1963.0
#         ...
# 352    1990.0
# 353    1998.0
# 354    1966.0
# 355    1962.0
# 356    1998.0
# Name: Year, Length: 357, dtype: float64

# %%
data.Year.isnull().sum()
# Out:
# 26

# %%
data.fillna({
            'Group':data.Group.mode(),
            'alma_mater':data.alma_mater.mode(),
            'undergraduate_major':data.undergraduate_major.mode(),
            'graduate_major':data.graduate_major.mode(),
            })
# Out:
#                       Name    Year  Group   Status birth_date  \
# 0          Joseph M. Acaba  2004.0   19.0   Active 1967-05-17
# 1           Loren W. Acton  1996.0   16.0  Retired 1936-03-07
# 2         James C. Adamson  1984.0   10.0  Retired 1946-03-03
# 3          Thomas D. Akers  1987.0   12.0  Retired 1951-05-20
# 4              Buzz Aldrin  1963.0    3.0  Retired 1930-01-20
# ..                     ...     ...    ...      ...        ...
# 352          David A. Wolf  1990.0   13.0  Retired 1956-08-23
# 353  Neil W. Woodward III   1998.0   17.0  Retired 1962-07-26
# 354       Alfred M. Worden  1966.0    5.0  Retired 1932-02-07
# 355          John W. Young  1962.0    2.0  Retired 1930-09-24
# 356        George D. Zamka  1998.0   17.0  Retired 1962-06-29
#
#            birth_place Gender  \
# 0        Inglewood, CA   Male
# 1         Lewiston, MT   Male
# 2           Warsaw, NY   Male
# 3        St. Louis, MO   Male
# 4        Montclair, NJ   Male
# ..                 ...    ...
# 352   Indianapolis, IN   Male
# 353        Chicago, IL   Male
# 354        Jackson, MI   Male
# 355  San Francisco, CA   Male
# 356    Jersey City, NJ   Male
#
#                                             alma_mater  \
# 0    University of California-Santa Barbara; Univer...
# 1     Montana State University; University of Colorado
# 2            US Military Academy; Princeton University
# 3                         University of Missouri-Rolla
# 4                             US Military Academy; MIT
# ..                                                 ...
# 352              Purdue University; Indiana University
# 353  MIT; University of Texas-Austin; George Washin...
# 354        US Military Academy; University of Michigan
# 355                    Georgia Institute of Technology
# 356  US Naval Academy; Florida Institute of Technology
#
#           undergraduate_major                            graduate_major  \
# 0                     Geology                                   Geology
# 1         Engineering Physics                             Solar Physics
# 2                 Engineering                     Aerospace Engineering
# 3         Applied Mathematics                       Applied Mathematics
# 4      Mechanical Engineering                              Astronautics
# ..                        ...                                       ...
# 352    Electrical Engineering                                  Medicine
# 353                   Physics              Physics; Business Management
# 354          Military Science  Aeronautical & Astronautical Engineering
# 355  Aeronautical Engineering                                       NaN
# 356               Mathematics                    Engineering Management
#
#     military_rank            military_branch  space_fights  space_flight(hr)  \
# 0             NaN                        NaN             2              3307
# 1             NaN                        NaN             1               190
# 2         Colonel          US Army (Retired)             2               334
# 3         Colonel     US Air Force (Retired)             4               814
# 4         Colonel     US Air Force (Retired)             2               289
# ..            ...                        ...           ...               ...
# 352           NaN                        NaN             3              4044
# 353     Commander                    US Navy             0                 0
# 354       Colonel     US Air Force (Retired)             1               295
# 355       Captain          US Navy (Retired)             6               835
# 356       Colonel  US Marine Corps (Retired)             2               692
#
#      space_walks  space_walks(hr)  \
# 0              2             13.0
# 1              0              0.0
# 2              0              0.0
# 3              4             29.0
# 4              2              8.0
# ..           ...              ...
# 352            7             41.0
# 353            0              0.0
# 354            1              0.5
# 355            3             20.0
# 356            0              0.0
#
#                                               Missions death_date  \
# 0               STS-119 (Discovery), ISS-31/32 (Soyuz)        NaT
# 1                                STS 51-F (Challenger)        NaT
# 2                 STS-28 (Columbia), STS-43 (Atlantis)        NaT
# 3    STS-41 (Discovery), STS-49 (Endeavor), STS-61 ...        NaT
# 4                                 Gemini 12, Apollo 11        NaT
# ..                                                 ...        ...
# 352  STS-58 (Columbia). STS-86/89 (Atlantis/Endeavo...        NaT
# 353                                                NaN        NaT
# 354                                          Apollo 15        NaT
# 355  Gemini 3, Gemini 10, Apollo 10, Apollo 16, STS...        NaT
# 356            STS-120 (Discovery), STS-130 (Endeavor)        NaT
#
#     death_mission
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ..            ...
# 352           NaN
# 353           NaN
# 354           NaN
# 355           NaN
# 356           NaN
#
# [357 rows x 19 columns]

# %%
data
# Out:
#                       Name    Year  Group   Status Birth Date  \
# 0          Joseph M. Acaba  2004.0   19.0   Active  5/17/1967
# 1           Loren W. Acton  1996.0    NaN  Retired   3/7/1936
# 2         James C. Adamson  1984.0   10.0  Retired   3/3/1946
# 3          Thomas D. Akers  1987.0   12.0  Retired  5/20/1951
# 4              Buzz Aldrin  1963.0    3.0  Retired  1/20/1930
# ..                     ...     ...    ...      ...        ...
# 352          David A. Wolf  1990.0   13.0  Retired  8/23/1956
# 353  Neil W. Woodward III   1998.0   17.0  Retired  7/26/1962
# 354       Alfred M. Worden  1966.0    5.0  Retired   2/7/1932
# 355          John W. Young  1962.0    2.0  Retired  9/24/1930
# 356        George D. Zamka  1998.0   17.0  Retired  6/29/1962
#
#            Birth Place Gender  \
# 0        Inglewood, CA   Male
# 1         Lewiston, MT   Male
# 2           Warsaw, NY   Male
# 3        St. Louis, MO   Male
# 4        Montclair, NJ   Male
# ..                 ...    ...
# 352   Indianapolis, IN   Male
# 353        Chicago, IL   Male
# 354        Jackson, MI   Male
# 355  San Francisco, CA   Male
# 356    Jersey City, NJ   Male
#
#                                             Alma Mater  \
# 0    University of California-Santa Barbara; Univer...
# 1     Montana State University; University of Colorado
# 2            US Military Academy; Princeton University
# 3                         University of Missouri-Rolla
# 4                             US Military Academy; MIT
# ..                                                 ...
# 352              Purdue University; Indiana University
# 353  MIT; University of Texas-Austin; George Washin...
# 354        US Military Academy; University of Michigan
# 355                    Georgia Institute of Technology
# 356  US Naval Academy; Florida Institute of Technology
#
#           Undergraduate Major                            Graduate Major  \
# 0                     Geology                                   Geology
# 1         Engineering Physics                             Solar Physics
# 2                 Engineering                     Aerospace Engineering
# 3         Applied Mathematics                       Applied Mathematics
# 4      Mechanical Engineering                              Astronautics
# ..                        ...                                       ...
# 352    Electrical Engineering                                  Medicine
# 353                   Physics              Physics; Business Management
# 354          Military Science  Aeronautical & Astronautical Engineering
# 355  Aeronautical Engineering                                       NaN
# 356               Mathematics                    Engineering Management
#
#     Military Rank            Military Branch  Space Flights  \
# 0             NaN                        NaN              2
# 1             NaN                        NaN              1
# 2         Colonel          US Army (Retired)              2
# 3         Colonel     US Air Force (Retired)              4
# 4         Colonel     US Air Force (Retired)              2
# ..            ...                        ...            ...
# 352           NaN                        NaN              3
# 353     Commander                    US Navy              0
# 354       Colonel     US Air Force (Retired)              1
# 355       Captain          US Navy (Retired)              6
# 356       Colonel  US Marine Corps (Retired)              2
#
#      Space Flight (hr)  Space Walks  Space Walks (hr)  \
# 0                 3307            2              13.0
# 1                  190            0               0.0
# 2                  334            0               0.0
# 3                  814            4              29.0
# 4                  289            2               8.0
# ..                 ...          ...               ...
# 352               4044            7              41.0
# 353                  0            0               0.0
# 354                295            1               0.5
# 355                835            3              20.0
# 356                692            0               0.0
#
#                                               Missions Death Date  \
# 0               STS-119 (Discovery), ISS-31/32 (Soyuz)        NaN
# 1                                STS 51-F (Challenger)        NaN
# 2                 STS-28 (Columbia), STS-43 (Atlantis)        NaN
# 3    STS-41 (Discovery), STS-49 (Endeavor), STS-61 ...        NaN
# 4                                 Gemini 12, Apollo 11        NaN
# ..                                                 ...        ...
# 352  STS-58 (Columbia). STS-86/89 (Atlantis/Endeavo...        NaN
# 353                                                NaN        NaN
# 354                                          Apollo 15        NaN
# 355  Gemini 3, Gemini 10, Apollo 10, Apollo 16, STS...        NaN
# 356            STS-120 (Discovery), STS-130 (Endeavor)        NaN
#
#     Death Mission
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ..            ...
# 352           NaN
# 353           NaN
# 354           NaN
# 355           NaN
# 356           NaN
#
# [357 rows x 19 columns]

# %%
data.fillna()

# %%
df = pd.read_excel("grouping.xlsx")
df
# Out:
#    ID    Names  Grades        Depts  Salaries
# 0   1     Asad      16     Accounts        NaN
# 1   2    Fahad      17     Taxation      123.0
# 2   3      NaN      18     Accounts      121.0
# 3   4   Afzal       19          NaN        NaN
# 4   5   Yasir       16  Information       99.0
# 5   6   Nasir       19          NaN      100.0
# 6   7      NaN      14     Accounts      123.0
# 7   8  Hassan       17  Information      122.0
# 8   9     Jami      17     Defence       156.0
# 9  10    Haseb      18          NaN      160.0

# %%
df.dropna(axis=0,how='any')
# Out:
#    ID    Names  Grades        Depts  Salaries
# 1   2    Fahad      17     Taxation      123.0
# 4   5   Yasir       16  Information       99.0
# 7   8  Hassan       17  Information      122.0
# 8   9     Jami      17     Defence       156.0

# %%
df.dropna(axis=1,how='any')
# Out:
#    ID  Grades
# 0   1      16
# 1   2      17
# 2   3      18
# 3   4      19
# 4   5      16
# 5   6      19
# 6   7      14
# 7   8      17
# 8   9      17
# 9  10      18

# %%
df.dropna(axis=0,how="all")
# Out:
#    ID    Names  Grades        Depts  Salaries
# 0   1     Asad      16     Accounts        NaN
# 1   2    Fahad      17     Taxation      123.0
# 2   3      NaN      18     Accounts      121.0
# 3   4   Afzal       19          NaN        NaN
# 4   5   Yasir       16  Information       99.0
# 5   6   Nasir       19          NaN      100.0
# 6   7      NaN      14     Accounts      123.0
# 7   8  Hassan       17  Information      122.0
# 8   9     Jami      17     Defence       156.0
# 9  10    Haseb      18          NaN      160.0

# %%
df.dropna(axis=1,how="all")
# Out:
#    ID    Names  Grades        Depts  Salaries
# 0   1     Asad      16     Accounts        NaN
# 1   2    Fahad      17     Taxation      123.0
# 2   3      NaN      18     Accounts      121.0
# 3   4   Afzal       19          NaN        NaN
# 4   5   Yasir       16  Information       99.0
# 5   6   Nasir       19          NaN      100.0
# 6   7      NaN      14     Accounts      123.0
# 7   8  Hassan       17  Information      122.0
# 8   9     Jami      17     Defence       156.0
# 9  10    Haseb      18          NaN      160.0

# %%
df['Na_Vals'] = np.nan

# %%
df.iloc[9:,:]=np.nan

# %%
df
# Out:
#     ID    Names  Grades        Depts  Salaries   Na_Vals
# 0  1.0     Asad    16.0     Accounts        NaN      NaN
# 1  2.0    Fahad    17.0     Taxation      123.0      NaN
# 2  3.0      NaN    18.0     Accounts      121.0      NaN
# 3  4.0   Afzal     19.0          NaN        NaN      NaN
# 4  5.0   Yasir     16.0  Information       99.0      NaN
# 5  6.0   Nasir     19.0          NaN      100.0      NaN
# 6  7.0      NaN    14.0     Accounts      123.0      NaN
# 7  8.0  Hassan     17.0  Information      122.0      NaN
# 8  9.0     Jami    17.0     Defence       156.0      NaN
# 9  NaN      NaN     NaN          NaN        NaN      NaN

# %%
df.dropna(axis=0, how='all')
# Out:
#     ID    Names  Grades        Depts  Salaries   Na_Vals
# 0  1.0     Asad    16.0     Accounts        NaN      NaN
# 1  2.0    Fahad    17.0     Taxation      123.0      NaN
# 2  3.0      NaN    18.0     Accounts      121.0      NaN
# 3  4.0   Afzal     19.0          NaN        NaN      NaN
# 4  5.0   Yasir     16.0  Information       99.0      NaN
# 5  6.0   Nasir     19.0          NaN      100.0      NaN
# 6  7.0      NaN    14.0     Accounts      123.0      NaN
# 7  8.0  Hassan     17.0  Information      122.0      NaN
# 8  9.0     Jami    17.0     Defence       156.0      NaN

# %%
df.dropna(axis=1, how='all')
# Out:
#     ID    Names  Grades        Depts  Salaries
# 0  1.0     Asad    16.0     Accounts        NaN
# 1  2.0    Fahad    17.0     Taxation      123.0
# 2  3.0      NaN    18.0     Accounts      121.0
# 3  4.0   Afzal     19.0          NaN        NaN
# 4  5.0   Yasir     16.0  Information       99.0
# 5  6.0   Nasir     19.0          NaN      100.0
# 6  7.0      NaN    14.0     Accounts      123.0
# 7  8.0  Hassan     17.0  Information      122.0
# 8  9.0     Jami    17.0     Defence       156.0
# 9  NaN      NaN     NaN          NaN        NaN

# %%
df
# Out:
#     ID    Names  Grades        Depts  Salaries   Na_Vals
# 0  1.0     Asad    16.0     Accounts        NaN      NaN
# 1  2.0    Fahad    17.0     Taxation      123.0      NaN
# 2  3.0      NaN    18.0     Accounts      121.0      NaN
# 3  4.0   Afzal     19.0          NaN        NaN      NaN
# 4  5.0   Yasir     16.0  Information       99.0      NaN
# 5  6.0   Nasir     19.0          NaN      100.0      NaN
# 6  7.0      NaN    14.0     Accounts      123.0      NaN
# 7  8.0  Hassan     17.0  Information      122.0      NaN
# 8  9.0     Jami    17.0     Defence       156.0      NaN
# 9  NaN      NaN     NaN          NaN        NaN      NaN

# %%
df.dropna(axis=0,thresh=5)
# Out:
#     ID    Names  Grades        Depts  Salaries   Na_Vals
# 1  2.0    Fahad    17.0     Taxation      123.0      NaN
# 4  5.0   Yasir     16.0  Information       99.0      NaN
# 7  8.0  Hassan     17.0  Information      122.0      NaN
# 8  9.0     Jami    17.0     Defence       156.0      NaN

# %%
df.dropna(axis=1,thresh=4)
# Out:
#     ID    Names  Grades        Depts  Salaries
# 0  1.0     Asad    16.0     Accounts        NaN
# 1  2.0    Fahad    17.0     Taxation      123.0
# 2  3.0      NaN    18.0     Accounts      121.0
# 3  4.0   Afzal     19.0          NaN        NaN
# 4  5.0   Yasir     16.0  Information       99.0
# 5  6.0   Nasir     19.0          NaN      100.0
# 6  7.0      NaN    14.0     Accounts      123.0
# 7  8.0  Hassan     17.0  Information      122.0
# 8  9.0     Jami    17.0     Defence       156.0
# 9  NaN      NaN     NaN          NaN        NaN

# %% [markdown]
# # Handling Duplicates Records

# %%
df.iloc[10:,:]=np.nan

# %%
df.iloc[8,:] = np.nan

# %%
df
# Out:
#     ID    Names  Grades        Depts  Salaries   Na_Vals
# 0  1.0     Asad    16.0     Accounts        NaN      NaN
# 1  2.0    Fahad    17.0     Taxation      123.0      NaN
# 2  3.0      NaN    18.0     Accounts      121.0      NaN
# 3  4.0   Afzal     19.0          NaN        NaN      NaN
# 4  5.0   Yasir     16.0  Information       99.0      NaN
# 5  6.0   Nasir     19.0          NaN      100.0      NaN
# 6  7.0      NaN    14.0     Accounts      123.0      NaN
# 7  8.0  Hassan     17.0  Information      122.0      NaN
# 8  NaN      NaN     NaN          NaN        NaN      NaN
# 9  NaN      NaN     NaN          NaN        NaN      NaN

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9     True
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates(subset=['Depts', 'Na_Vals'])
# Out:
#     ID   Names  Grades        Depts  Salaries   Na_Vals
# 0  1.0    Asad    16.0     Accounts        NaN      NaN
# 1  2.0   Fahad    17.0     Taxation      123.0      NaN
# 3  4.0  Afzal     19.0          NaN        NaN      NaN
# 4  5.0  Yasir     16.0  Information       99.0      NaN
