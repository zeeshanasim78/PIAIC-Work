# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Creating DataFrame

# %%
# using lists
student_data = [
    [100,80,10],
    [90,70,7],
    [120,100,14],
    [80,50,2]
]

pd.DataFrame(student_data,columns=['iq','marks','package'])
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2

# %%
# using dicts

student_dict = {
    'name':['ali','basit','raza','sami','atif','sohail'],
    'iq':[100,90,120,80,0,0],
    'marks':[80,70,100,50,0,0],
    'package':[10,7,14,2,0,0]
}

students = pd.DataFrame(student_dict)
students.set_index('name',inplace=True)
students
# Out:
#          iq  marks  package
# name
# ali     100     80       10
# basit    90     70        7
# raza    120    100       14
# sami     80     50        2
# atif      0      0        0
# sohail    0      0        0

# %%
# using read_csv
movies = pd.read_csv('movies.csv')
movies.head(2)
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 1             Battalion 609  tt9472208
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 1             Battalion 609             Battalion 609         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
# 1             2019     131               War          4.1          73
#
#                                                story  \
# 0  Divided over five chapters  the film chronicle...
# 1  The story revolves around a cricket match betw...
#
#                                              summary tagline  \
# 0  Indian army special forces execute a covert op...     NaN
# 1  The story of Battalion 609 revolves around a c...     NaN
#
#                                               actors wins_nominations  \
# 0  Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...           4 wins
# 1  Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...              NaN
#
#               release_date
# 0    11 January 2019 (USA)
# 1  11 January 2019 (India)

# %%
ipl = pd.read_csv('ipl-matches.csv')
ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
#                                         Team2Players      Umpire1      Umpire2
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...  CB Gaffaney  Nitin Menon
# 1  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...  CB Gaffaney  Nitin Menon

# %% [markdown]
# ### DataFrame Attributes and Methods

# %%
# shape
print(movies.shape)
print(ipl.shape)
# Out:
# (1629, 18)
# (950, 20)

# %%
# dtypes
print(movies.dtypes)
print("**********")
print(ipl.dtypes)
# Out:
# title_x              object
# imdb_id              object
# poster_path          object
# wiki_link            object
# title_y              object
# original_title       object
# is_adult              int64
# year_of_release       int64
# runtime              object
# genres               object
# imdb_rating         float64
# imdb_votes            int64
# story                object
# summary              object
# tagline              object
# actors               object
# wins_nominations     object
# release_date         object
# dtype: object
# **********
# ID                   int64
# City                object
# Date                object
# Season              object
# MatchNumber         object
# Team1               object
# Team2               object
# Venue               object
# TossWinner          object
# TossDecision        object
# SuperOver           object
# WinningTeam         object
# WonBy               object
# Margin             float64
# method              object
# Player_of_Match     object
# Team1Players        object
# Team2Players        object
# Umpire1             object
# Umpire2             object
# dtype: object

# %%
# index
print(movies.index)
print(ipl.index)
# Out:
# RangeIndex(start=0, stop=1629, step=1)
# RangeIndex(start=0, stop=950, step=1)

# %%
# columns
print(movies.columns)
print(ipl.columns)
print(students.columns)
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')
# Index(['iq', 'percent', 'lpa'], dtype='object')

# %%
# values
print(students.values)  # return dataframe in numpy array form
print(ipl.values)
# Out:
# [[100  80  10]
#  [ 90  70   7]
#  [120 100  14]
#  [ 80  50   2]
#  [  0   0   0]
#  [  0   0   0]]
# [[1312200 'Ahmedabad' '2022-05-29' ...
#   "['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pandya', 'DA Miller', 'R Tewatia', 'Rashid Khan', 'R Sai Kishore', 'LH Ferguson', 'Yash Dayal', 'Mohammed Shami']"
#   'CB Gaffaney' 'Nitin Menon']
#  [1312199 'Ahmedabad' '2022-05-27' ...
#   "['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D Padikkal', 'SO Hetmyer', 'R Parag', 'R Ashwin', 'TA Boult', 'YS Chahal', 'M Prasidh Krishna', 'OC McCoy']"
#   'CB Gaffaney' 'Nitin Menon']
#  [1312198 'Kolkata' '2022-05-25' ...
#   "['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda', 'MP Stoinis', 'E Lewis', 'KH Pandya', 'PVD Chameera', 'Mohsin Khan', 'Avesh Khan', 'Ravi Bishnoi']"
#   'J Madanagopal' 'MA Gough']
#  ...
#  [335984 'Delhi' '2008-04-19' ...
#   "['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif', 'DS Lehmann', 'RA Jadeja', 'M Rawat', 'D Salunkhe', 'SK Warne', 'SK Trivedi', 'MM Patel']"
#   'Aleem Dar' 'GA Pratapkumar']
#  [335983 'Chandigarh' '2008-04-19' ...
#   "['PA Patel', 'ML Hayden', 'MEK Hussey', 'MS Dhoni', 'SK Raina', 'JDP Oram', 'S Badrinath', 'Joginder Sharma', 'P Amarnath', 'MS Gony', 'M Muralitharan']"
#   'MR Benson' 'SL Shastri']
#  [335982 'Bangalore' '2008-04-18' ...
#   "['SC Ganguly', 'BB McCullum', 'RT Ponting', 'DJ Hussey', 'Mohammad Hafeez', 'LR Shukla', 'WP Saha', 'AB Agarkar', 'AB Dinda', 'M Kartik', 'I Sharma']"
#   'Asad Rauf' 'RE Koertzen']]

# %%
# head and tail
movies.head(2)
# Out:
#           title_x    imdb_id  \
# 11      Gully Boy  tt2395469
# 34  Yeh Hai India  tt5525846
#
#                                           poster_path  \
# 11  https://upload.wikimedia.org/wikipedia/en/thum...
# 34  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                       wiki_link        title_y original_title  \
# 11      https://en.wikipedia.org/wiki/Gully_Boy      Gully Boy      Gully Boy
# 34  https://en.wikipedia.org/wiki/Yeh_Hai_India  Yeh Hai India  Yeh Hai India
#
#     is_adult  year_of_release runtime                  genres  imdb_rating  \
# 11         0             2019     153             Drama|Music          8.2
# 34         0             2017     128  Action|Adventure|Drama          5.7
#
#     imdb_votes                                              story  \
# 11       22440  Gully Boy is a film about a 22-year-old boy "M...
# 34         169  Yeh Hai India  follows the story of a 25 years...
#
#                                               summary  \
# 11  A coming-of-age story based on the lives of st...
# 34  Yeh Hai India  follows the story of a 25 years...
#
#                     tagline  \
# 11        Apna Time Aayega!
# 34  A Film for Every Indian
#
#                                                actors        wins_nominations  \
# 11  Ranveer Singh|Alia Bhatt|Siddhant Chaturvedi|V...  6 wins & 3 nominations
# 34   Gavie Chahal|Mohan Agashe|Mohan Joshi|Lom Harsh|   2 wins & 1 nomination
#
#               release_date Country     lead actor
# 11  14 February 2019 (USA)   India  Ranveer Singh
# 34     24 May 2019 (India)   India   Gavie Chahal

# %%
ipl.tail(2)
# Out:
#          ID        City        Date   Season MatchNumber  \
# 948  335983  Chandigarh  2008-04-19  2007/08           2
# 949  335982   Bangalore  2008-04-18  2007/08           1
#
#                            Team1                  Team2  \
# 948              Kings XI Punjab    Chennai Super Kings
# 949  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 948  Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# 949                       M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#     TossDecision SuperOver            WinningTeam WonBy  Margin method  \
# 948          bat         N    Chennai Super Kings  Runs    33.0    NaN
# 949        field         N  Kolkata Knight Riders  Runs   140.0    NaN
#
#     Player_of_Match                                       Team1Players  \
# 948      MEK Hussey  ['K Goel', 'JR Hopes', 'KC Sangakkara', 'Yuvra...
# 949     BB McCullum  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
#
#                                           Team2Players    Umpire1      Umpire2
# 948  ['PA Patel', 'ML Hayden', 'MEK Hussey', 'MS Dh...  MR Benson   SL Shastri
# 949  ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...  Asad Rauf  RE Koertzen

# %%
# sample
ipl.sample(5) # returns ramdom samples here 5 samples
# Out:
#           ID       City        Date Season MatchNumber  \
# 773   501199  Hyderabad  2011-04-09   2011           2
# 395   980975    Kolkata  2016-05-08   2016          38
# 280  1136594     Indore  2018-05-04   2018          34
# 477   829737  Bangalore  2015-04-19   2015          16
# 54   1304066     Mumbai  2022-04-10   2022          20
#
#                            Team1                 Team2  \
# 773              Deccan Chargers      Rajasthan Royals
# 395        Kolkata Knight Riders         Gujarat Lions
# 280              Kings XI Punjab        Mumbai Indians
# 477  Royal Challengers Bangalore        Mumbai Indians
# 54              Rajasthan Royals  Lucknow Super Giants
#
#                                          Venue                   TossWinner  \
# 773  Rajiv Gandhi International Stadium, Uppal             Rajasthan Royals
# 395                               Eden Gardens                Gujarat Lions
# 280                     Holkar Cricket Stadium               Mumbai Indians
# 477                      M Chinnaswamy Stadium  Royal Challengers Bangalore
# 54                    Wankhede Stadium, Mumbai         Lucknow Super Giants
#
#     TossDecision SuperOver       WinningTeam    WonBy  Margin method  \
# 773        field         N  Rajasthan Royals  Wickets     8.0    NaN
# 395        field         N     Gujarat Lions  Wickets     5.0    NaN
# 280        field         N    Mumbai Indians  Wickets     6.0    NaN
# 477        field         N    Mumbai Indians     Runs    18.0    NaN
# 54         field         N  Rajasthan Royals     Runs     3.0    NaN
#
#      Player_of_Match                                       Team1Players  \
# 773       SK Trivedi  ['S Dhawan', 'IR Jaggi', 'KC Sangakkara', 'B C...
# 395          P Kumar  ['RV Uthappa', 'G Gambhir', 'MK Pandey', 'SA Y...
# 280         SA Yadav  ['KL Rahul', 'CH Gayle', 'Yuvraj Singh', 'KK N...
# 477  Harbhajan Singh  ['CH Gayle', 'MS Bisla', 'V Kohli', 'KD Karthi...
# 54         YS Chahal  ['JC Buttler', 'D Padikkal', 'SV Samson', 'HE ...
#
#                                           Team2Players         Umpire1  \
# 773  ['AG Paunikar', 'R Dravid', 'J Botha', 'LRPL T...     RE Koertzen
# 395  ['DR Smith', 'BB McCullum', 'SK Raina', 'KD Ka...       M Erasmus
# 280  ['SA Yadav', 'E Lewis', 'Ishan Kishan', 'HH Pa...     AY Dandekar
# 477  ['LMP Simmons', 'PA Patel', 'UBT Chand', 'RG S...  RK Illingworth
# 54   ['KL Rahul', 'Q de Kock', 'K Gowtham', 'JO Hol...    AK Chaudhary
#
#           Umpire2
# 773   SK Tarapore
# 395     RJ Tucker
# 280        S Ravi
# 477   VA Kulkarni
# 54   Tapan Sharma

# %%
# info
movies.info()  # returns basic info of data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 298 entries, 11 to 1623
# Data columns (total 20 columns):
# title_x             298 non-null object
# imdb_id             298 non-null object
# poster_path         298 non-null object
# wiki_link           298 non-null object
# title_y             298 non-null object
# original_title      298 non-null object
# is_adult            298 non-null int64
# year_of_release     298 non-null int64
# runtime             298 non-null object
# genres              298 non-null object
# imdb_rating         298 non-null float64
# imdb_votes          298 non-null int64
# story               298 non-null object
# summary             298 non-null object
# tagline             298 non-null object
# actors              298 non-null object
# wins_nominations    298 non-null object
# release_date        298 non-null object
# Country             298 non-null object
# lead actor          298 non-null object
# dtypes: float64(1), int64(3), object(16)
# memory usage: 48.9+ KB

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
# ID                 950 non-null int32
# City               899 non-null object
# Date               950 non-null object
# Season             950 non-null object
# MatchNumber        950 non-null object
# Team1              950 non-null category
# Team2              950 non-null category
# Venue              950 non-null object
# TossWinner         950 non-null object
# TossDecision       950 non-null object
# SuperOver          946 non-null object
# WinningTeam        946 non-null object
# WonBy              950 non-null object
# Margin             932 non-null float64
# method             19 non-null object
# Player_of_Match    946 non-null object
# Team1Players       950 non-null object
# Team2Players       950 non-null object
# Umpire1            950 non-null object
# Umpire2            950 non-null object
# dtypes: category(2), float64(1), int32(1), object(16)
# memory usage: 133.4+ KB

# %%
# describe
movies.describe()  # returns basic statistics of data (only numerical value columns)
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count     298.0       298.000000   298.000000     298.000000
# mean        0.0      2008.845638     6.361409   14193.617450
# std         0.0         5.192230     1.340469   26724.554265
# min         0.0      2001.000000     1.700000      25.000000
# 25%         0.0      2004.000000     5.400000    1801.250000
# 50%         0.0      2008.000000     6.600000    5225.500000
# 75%         0.0      2013.000000     7.400000   15041.250000
# max         0.0      2019.000000     8.500000  310481.000000

# %%
ipl.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %%
# isnull
movies.isnull().sum()  # returns number of null values in each columns
# Out:
# title_x             0
# imdb_id             0
# poster_path         0
# wiki_link           0
# title_y             0
# original_title      0
# is_adult            0
# year_of_release     0
# runtime             0
# genres              0
# imdb_rating         0
# imdb_votes          0
# story               0
# summary             0
# tagline             0
# actors              0
# wins_nominations    0
# release_date        0
# Country             0
# lead actor          0
# dtype: int64

# %%
# duplicated
movies.duplicated().sum()# returns all duplicated values in data
# Out:
# 0

# %%
students.duplicated().sum()
# Out:
# 1

# %%
# rename
students
# Out:
#          iq  percent  lpa
# name
# ali     100       80   10
# basit    90       70    7
# raza    120      100   14
# sami     80       50    2
# atif      0        0    0
# sohail    0        0    0

# %%
students.rename(columns={'marks':'percent','package':'lpa'},inplace=True)
# renames the columns names

# %% [markdown]
# ### Math Methods

# %%
# sum -> axis argument
students.sum(axis=0)

# sum all the values in a columns due to axis is 0
# Out:
# iq         390
# percent    300
# lpa         33
# dtype: int64

# %%
students.mean(axis=1)
# sum all the values in a row due to axis is 1
# Out:
# name
# ali       63.333333
# basit     55.666667
# raza      78.000000
# sami      44.000000
# atif       0.000000
# sohail     0.000000
# dtype: float64

# %%
students.var()  # returns the variance of each column
# Out:
# iq         2710.0
# percent    1760.0
# lpa          33.5
# dtype: float64

# %% [markdown]
# ### Selecting cols from a DataFrame

# %%
# single cols
movies['title_x']
# Out:
# 11                    Gully Boy
# 34                Yeh Hai India
# 37            Article 15 (film)
# 87                      Aiyaary
# 96             Raid (2018 film)
#                  ...
# 1600                     Kasoor
# 1601           Maya (2001 film)
# 1607    Nayak (2001 Hindi film)
# 1621                    Tum Bin
# 1623                   Zubeidaa
# Name: title_x, Length: 298, dtype: object

# %%
ipl['Venue']
# Out:
# 0                Narendra Modi Stadium, Ahmedabad
# 1                Narendra Modi Stadium, Ahmedabad
# 2                           Eden Gardens, Kolkata
# 3                           Eden Gardens, Kolkata
# 4                        Wankhede Stadium, Mumbai
#                           ...
# 945                                  Eden Gardens
# 946                              Wankhede Stadium
# 947                              Feroz Shah Kotla
# 948    Punjab Cricket Association Stadium, Mohali
# 949                         M Chinnaswamy Stadium
# Name: Venue, Length: 950, dtype: object

# %%
# multiple cols
movies[['year_of_release','actors','title_x']]# to select multiple columns we pass list pf columns we need
# Out:
#       year_of_release                                             actors  \
# 11               2019  Ranveer Singh|Alia Bhatt|Siddhant Chaturvedi|V...
# 34               2017   Gavie Chahal|Mohan Agashe|Mohan Joshi|Lom Harsh|
# 37               2019  Ayushmann Khurrana|Nassar|Manoj Pahwa|Kumud Mi...
# 87               2018  Sidharth Malhotra|Manoj Bajpayee|Rakul Preet S...
# 96               2018  Ajay Devgn|Saurabh Shukla|Ileana D'Cruz|Amit S...
# ...               ...                                                ...
# 1600             2001  Divya Dutta|Sucheta Paushe|Lisa Ray|Apoorva Ag...
# 1601             2001  Anant Nag|Mita Vasisht|Nitya Shetty|Nikhil Yad...
# 1607             2001  Anil Kapoor|Rani Mukerji|Amrish Puri|Johnny Le...
# 1621             2001  Priyanshu Chatterjee|Himanshu Malik|Sandali Si...
# 1623             2001  Karisma Kapoor|Rekha|Manoj Bajpayee|Rajit Kapo...
#
#                       title_x
# 11                  Gully Boy
# 34              Yeh Hai India
# 37          Article 15 (film)
# 87                    Aiyaary
# 96           Raid (2018 film)
# ...                       ...
# 1600                   Kasoor
# 1601         Maya (2001 film)
# 1607  Nayak (2001 Hindi film)
# 1621                  Tum Bin
# 1623                 Zubeidaa
#
# [298 rows x 3 columns]

# %%
ipl[['Team1','Team2','WinningTeam']]
# Out:
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                      WinningTeam
# 0                 Gujarat Titans
# 1               Rajasthan Royals
# 2    Royal Challengers Bangalore
# 3                 Gujarat Titans
# 4                   Punjab Kings
# ..                           ...
# 945        Kolkata Knight Riders
# 946  Royal Challengers Bangalore
# 947             Delhi Daredevils
# 948          Chennai Super Kings
# 949        Kolkata Knight Riders
#
# [950 rows x 3 columns]

# %% [markdown]
# ### Selecting rows from a DataFrame
#
# - **iloc** - searches using index positions
# - **loc** - searches using index labels

# %%
movies
# Out:
#                       title_x     imdb_id  \
# 11                  Gully Boy   tt2395469
# 34              Yeh Hai India   tt5525846
# 37          Article 15 (film)  tt10324144
# 87                    Aiyaary   tt6774212
# 96           Raid (2018 film)   tt7363076
# ...                       ...         ...
# 1600                   Kasoor   tt0272688
# 1601         Maya (2001 film)   tt0299027
# 1607  Nayak (2001 Hindi film)   tt0291376
# 1621                  Tum Bin   tt0290326
# 1623                 Zubeidaa   tt0255713
#
#                                             poster_path  \
# 11    https://upload.wikimedia.org/wikipedia/en/thum...
# 34    https://upload.wikimedia.org/wikipedia/en/thum...
# 37    https://upload.wikimedia.org/wikipedia/en/thum...
# 87    https://upload.wikimedia.org/wikipedia/en/thum...
# 96    https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 1600  https://upload.wikimedia.org/wikipedia/en/thum...
# 1601  https://upload.wikimedia.org/wikipedia/en/thum...
# 1607  https://upload.wikimedia.org/wikipedia/en/thum...
# 1621  https://upload.wikimedia.org/wikipedia/en/thum...
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link  \
# 11              https://en.wikipedia.org/wiki/Gully_Boy
# 34          https://en.wikipedia.org/wiki/Yeh_Hai_India
# 37      https://en.wikipedia.org/wiki/Article_15_(film)
# 87                https://en.wikipedia.org/wiki/Aiyaary
# 96       https://en.wikipedia.org/wiki/Raid_(2018_film)
# ...                                                 ...
# 1600               https://en.wikipedia.org/wiki/Kasoor
# 1601     https://en.wikipedia.org/wiki/Maya_(2001_film)
# 1607  https://en.wikipedia.org/wiki/Nayak_(2001_Hind...
# 1621              https://en.wikipedia.org/wiki/Tum_Bin
# 1623             https://en.wikipedia.org/wiki/Zubeidaa
#
#                                title_y                    original_title  \
# 11                           Gully Boy                         Gully Boy
# 34                       Yeh Hai India                     Yeh Hai India
# 37                          Article 15                        Article 15
# 87                             Aiyaary                           Aiyaary
# 96                                Raid                              Raid
# ...                                ...                               ...
# 1600                            Kasoor                            Kasoor
# 1601                              Maya                              Maya
# 1607              Nayak: The Real Hero              Nayak: The Real Hero
# 1621  Tum Bin...: Love Will Find a Way  Tum Bin...: Love Will Find a Way
# 1623                          Zubeidaa                          Zubeidaa
#
#       is_adult  year_of_release runtime                   genres  imdb_rating  \
# 11           0             2019     153              Drama|Music          8.2
# 34           0             2017     128   Action|Adventure|Drama          5.7
# 37           0             2019     130              Crime|Drama          8.3
# 87           0             2018     157          Action|Thriller          5.2
# 96           0             2018     122       Action|Crime|Drama          7.4
# ...        ...              ...     ...                      ...          ...
# 1600         0             2001     151   Drama|Mystery|Thriller          6.0
# 1601         0             2001     105                    Drama          7.0
# 1607         0             2001     187    Action|Drama|Thriller          7.8
# 1621         0             2001     158            Drama|Romance          7.5
# 1623         0             2001     153  Biography|Drama|History          6.2
#
#       imdb_votes                                              story  \
# 11         22440  Gully Boy is a film about a 22-year-old boy "M...
# 34           169  Yeh Hai India  follows the story of a 25 years...
# 37         13417  In the rural heartlands of India  an upright p...
# 87          3538  General Gurinder Singh comes with a proposal t...
# 96         13159  Set in the 80s in Uttar Pradesh  India  Raid i...
# ...          ...                                                ...
# 1600         801  Shekar Saxena is arrested and charged with the...
# 1601         277  For 12 year-old Maya  life is very simple in h...
# 1607       12522  Employed as a camera-man at a popular televisi...
# 1621        2879  Shekar and Amar meet at a party where Amar ask...
# 1623        1384  The film begins with Riyaz (Rajat Kapoor)  Zub...
#
#                                                 summary  \
# 11    A coming-of-age story based on the lives of st...
# 34    Yeh Hai India  follows the story of a 25 years...
# 37    In the rural heartlands of India  an upright p...
# 87    After finding out about an illegal arms deal  ...
# 96    A fearless income tax officer raids the mansio...
# ...                                                 ...
# 1600  Shekhar appoints Simran  a lawyer with an impe...
# 1601  MAYA is a coming of age story set against an '...
# 1607  A man accepts a challenge by the chief ministe...
# 1621  Shekhar accidentally kills his associate Amar ...
# 1623  Zubeidaa  an aspiring Muslim actress  marries ...
#
#                                                 tagline  \
# 11                                    Apna Time Aayega!
# 34                              A Film for Every Indian
# 37               Farq Bahut Kar Liya| Ab Farq Laayenge.
# 87                                The Ultimate Trickery
# 96                  Heroes don't always come in uniform
# ...                                                 ...
# 1600                             A dangerous passion...
# 1601  A child's innocence shattered by unreal tradit...
# 1607                                    Fight the power
# 1621                               Love will find a way
# 1623                            The Story of a Princess
#
#                                                  actors  \
# 11    Ranveer Singh|Alia Bhatt|Siddhant Chaturvedi|V...
# 34     Gavie Chahal|Mohan Agashe|Mohan Joshi|Lom Harsh|
# 37    Ayushmann Khurrana|Nassar|Manoj Pahwa|Kumud Mi...
# 87    Sidharth Malhotra|Manoj Bajpayee|Rakul Preet S...
# 96    Ajay Devgn|Saurabh Shukla|Ileana D'Cruz|Amit S...
# ...                                                 ...
# 1600  Divya Dutta|Sucheta Paushe|Lisa Ray|Apoorva Ag...
# 1601  Anant Nag|Mita Vasisht|Nitya Shetty|Nikhil Yad...
# 1607  Anil Kapoor|Rani Mukerji|Amrish Puri|Johnny Le...
# 1621  Priyanshu Chatterjee|Himanshu Malik|Sandali Si...
# 1623  Karisma Kapoor|Rekha|Manoj Bajpayee|Rajit Kapo...
#
#              wins_nominations               release_date Country  \
# 11     6 wins & 3 nominations     14 February 2019 (USA)   India
# 34      2 wins & 1 nomination        24 May 2019 (India)   India
# 37                      1 win         28 June 2019 (USA)   India
# 87               1 nomination     16 February 2018 (USA)   India
# 96     2 wins & 3 nominations      16 March 2018 (India)   India
# ...                       ...                        ...     ...
# 1600            2 nominations    2 February 2001 (India)   India
# 1601   2 wins & 4 nominations  16 January 2002 (Belgium)   India
# 1607            2 nominations   7 September 2001 (India)   India
# 1621            6 nominations       13 July 2001 (India)   India
# 1623  3 wins & 13 nominations    19 January 2001 (India)   India
#
#                 lead actor
# 11           Ranveer Singh
# 34            Gavie Chahal
# 37      Ayushmann Khurrana
# 87       Sidharth Malhotra
# 96              Ajay Devgn
# ...                    ...
# 1600           Divya Dutta
# 1601             Anant Nag
# 1607           Anil Kapoor
# 1621  Priyanshu Chatterjee
# 1623        Karisma Kapoor
#
# [298 rows x 20 columns]

# %%
# single row
movies.iloc[5]
# Out:
# title_x                                                      Baaghi 2
# imdb_id                                                     tt6843812
# poster_path         https://upload.wikimedia.org/wikipedia/en/thum...
# wiki_link                      https://en.wikipedia.org/wiki/Baaghi_2
# title_y                                                      Baaghi 2
# original_title                                               Baaghi 2
# is_adult                                                            0
# year_of_release                                                  2018
# runtime                                                           137
# genres                                                Action|Thriller
# imdb_rating                                                         5
# imdb_votes                                                       7657
# story               Ronnie is serving in the Indian army.He gets a...
# summary             A battle-hardened army officer squares off aga...
# tagline                                                Rebel for love
# actors              Tiger Shroff|Disha Patani|Manoj Bajpayee|Rande...
# wins_nominations                                3 wins & 1 nomination
# release_date                                      30 March 2018 (USA)
# Country                                                         India
# lead actor                                               Tiger Shroff
# Name: 99, dtype: object

# %%
# multiple row
movies.iloc[:5]
# Out:
#               title_x     imdb_id  \
# 11          Gully Boy   tt2395469
# 34      Yeh Hai India   tt5525846
# 37  Article 15 (film)  tt10324144
# 87            Aiyaary   tt6774212
# 96   Raid (2018 film)   tt7363076
#
#                                           poster_path  \
# 11  https://upload.wikimedia.org/wikipedia/en/thum...
# 34  https://upload.wikimedia.org/wikipedia/en/thum...
# 37  https://upload.wikimedia.org/wikipedia/en/thum...
# 87  https://upload.wikimedia.org/wikipedia/en/thum...
# 96  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                           wiki_link        title_y  \
# 11          https://en.wikipedia.org/wiki/Gully_Boy      Gully Boy
# 34      https://en.wikipedia.org/wiki/Yeh_Hai_India  Yeh Hai India
# 37  https://en.wikipedia.org/wiki/Article_15_(film)     Article 15
# 87            https://en.wikipedia.org/wiki/Aiyaary        Aiyaary
# 96   https://en.wikipedia.org/wiki/Raid_(2018_film)           Raid
#
#    original_title  is_adult  year_of_release runtime                  genres  \
# 11      Gully Boy         0             2019     153             Drama|Music
# 34  Yeh Hai India         0             2017     128  Action|Adventure|Drama
# 37     Article 15         0             2019     130             Crime|Drama
# 87        Aiyaary         0             2018     157         Action|Thriller
# 96           Raid         0             2018     122      Action|Crime|Drama
#
#     imdb_rating  imdb_votes  \
# 11          8.2       22440
# 34          5.7         169
# 37          8.3       13417
# 87          5.2        3538
# 96          7.4       13159
#
#                                                 story  \
# 11  Gully Boy is a film about a 22-year-old boy "M...
# 34  Yeh Hai India  follows the story of a 25 years...
# 37  In the rural heartlands of India  an upright p...
# 87  General Gurinder Singh comes with a proposal t...
# 96  Set in the 80s in Uttar Pradesh  India  Raid i...
#
#                                               summary  \
# 11  A coming-of-age story based on the lives of st...
# 34  Yeh Hai India  follows the story of a 25 years...
# 37  In the rural heartlands of India  an upright p...
# 87  After finding out about an illegal arms deal  ...
# 96  A fearless income tax officer raids the mansio...
#
#                                    tagline  \
# 11                       Apna Time Aayega!
# 34                 A Film for Every Indian
# 37  Farq Bahut Kar Liya| Ab Farq Laayenge.
# 87                   The Ultimate Trickery
# 96     Heroes don't always come in uniform
#
#                                                actors        wins_nominations  \
# 11  Ranveer Singh|Alia Bhatt|Siddhant Chaturvedi|V...  6 wins & 3 nominations
# 34   Gavie Chahal|Mohan Agashe|Mohan Joshi|Lom Harsh|   2 wins & 1 nomination
# 37  Ayushmann Khurrana|Nassar|Manoj Pahwa|Kumud Mi...                   1 win
# 87  Sidharth Malhotra|Manoj Bajpayee|Rakul Preet S...            1 nomination
# 96  Ajay Devgn|Saurabh Shukla|Ileana D'Cruz|Amit S...  2 wins & 3 nominations
#
#               release_date Country          lead actor
# 11  14 February 2019 (USA)   India       Ranveer Singh
# 34     24 May 2019 (India)   India        Gavie Chahal
# 37      28 June 2019 (USA)   India  Ayushmann Khurrana
# 87  16 February 2018 (USA)   India   Sidharth Malhotra
# 96   16 March 2018 (India)   India          Ajay Devgn

# %%
# fancy indexing
movies.iloc[[0,4,5]]
# Out:
#              title_x    imdb_id  \
# 11         Gully Boy  tt2395469
# 96  Raid (2018 film)  tt7363076
# 99          Baaghi 2  tt6843812
#
#                                           poster_path  \
# 11  https://upload.wikimedia.org/wikipedia/en/thum...
# 96  https://upload.wikimedia.org/wikipedia/en/thum...
# 99  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                          wiki_link    title_y original_title  \
# 11         https://en.wikipedia.org/wiki/Gully_Boy  Gully Boy      Gully Boy
# 96  https://en.wikipedia.org/wiki/Raid_(2018_film)       Raid           Raid
# 99          https://en.wikipedia.org/wiki/Baaghi_2   Baaghi 2       Baaghi 2
#
#     is_adult  year_of_release runtime              genres  imdb_rating  \
# 11         0             2019     153         Drama|Music          8.2
# 96         0             2018     122  Action|Crime|Drama          7.4
# 99         0             2018     137     Action|Thriller          5.0
#
#     imdb_votes                                              story  \
# 11       22440  Gully Boy is a film about a 22-year-old boy "M...
# 96       13159  Set in the 80s in Uttar Pradesh  India  Raid i...
# 99        7657  Ronnie is serving in the Indian army.He gets a...
#
#                                               summary  \
# 11  A coming-of-age story based on the lives of st...
# 96  A fearless income tax officer raids the mansio...
# 99  A battle-hardened army officer squares off aga...
#
#                                 tagline  \
# 11                    Apna Time Aayega!
# 96  Heroes don't always come in uniform
# 99                       Rebel for love
#
#                                                actors        wins_nominations  \
# 11  Ranveer Singh|Alia Bhatt|Siddhant Chaturvedi|V...  6 wins & 3 nominations
# 96  Ajay Devgn|Saurabh Shukla|Ileana D'Cruz|Amit S...  2 wins & 3 nominations
# 99  Tiger Shroff|Disha Patani|Manoj Bajpayee|Rande...   3 wins & 1 nomination
#
#               release_date Country     lead actor
# 11  14 February 2019 (USA)   India  Ranveer Singh
# 96   16 March 2018 (India)   India     Ajay Devgn
# 99     30 March 2018 (USA)   India   Tiger Shroff

# %%
# loc
students
# Out:
#          iq  percent  lpa
# name
# ali     100       80   10
# basit    90       70    7
# raza    120      100   14
# sami     80       50    2
# atif      0        0    0
# sohail    0        0    0

# %%
students.loc['raza']
# Out:
# iq         120
# percent    100
# lpa         14
# Name: raza, dtype: int64

# %%
students.loc['raza':'atif', 'iq']
# Out:
# name
# raza    120
# sami     80
# atif      0
# Name: iq, dtype: int64

# %%
students.loc[['raza','ali','sami']]
# Out:
#        iq  percent  lpa
# name
# raza  120      100   14
# ali   100       80   10
# sami   80       50    2

# %%
students.iloc[[0,3,4]]
# Out:
#        iq  percent  lpa
# name
# ali   100       80   10
# sami   80       50    2
# atif    0        0    0

# %% [markdown]
# ### Selecting both rows and cols

# %%
movies.iloc[0:3,0:3]
# Out:
#               title_x     imdb_id  \
# 11          Gully Boy   tt2395469
# 34      Yeh Hai India   tt5525846
# 37  Article 15 (film)  tt10324144
#
#                                           poster_path
# 11  https://upload.wikimedia.org/wikipedia/en/thum...
# 34  https://upload.wikimedia.org/wikipedia/en/thum...
# 37  https://upload.wikimedia.org/wikipedia/en/thum...

# %%
movies.loc[0:2,'title_x':'poster_path']
# Out:
# Empty DataFrame
# Columns: [title_x, imdb_id, poster_path]
# Index: []

# %% [markdown]
# ### Filtering a DataFrame

# %%
ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
#                                         Team2Players      Umpire1      Umpire2
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...  CB Gaffaney  Nitin Menon
# 1  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...  CB Gaffaney  Nitin Menon

# %%
# find all the final winners

mask = ipl['MatchNumber'] == 'Final'

new_df = ipl[mask]

new_df[['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
ipl[ipl['MatchNumber'] == 'Final'][['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
# how many super over finishes have occured
ipl[ipl['SuperOver'] == 'Y'].shape[0]
# Out:
# 14

# %%
# how many matches has csk won in kolkata

ipl[(ipl['City'] == 'Kolkata') & (ipl['WinningTeam'] == 'Chennai Super Kings')].shape[0]
# Out:
# 5

# %%
# toss winner is match winner in percentage
(ipl[ipl['TossWinner'] == ipl['WinningTeam']].shape[0]/ipl.shape[0])*100
# Out:
# 51.473684210526315

# %%
# movies with rating higher than 8 and votes>10000
movies[(movies['imdb_rating'] > 8.5) & (movies['imdb_votes'] > 10000)].shape[0]
# Out:
# 0

# %%
# Action movies with rating higher than 7.5
# mask1 = movies['genres'].str.split('|').apply(lambda x:'Action' in x)
mask1 = movies['genres'].str.contains('Action')
mask2 = movies['imdb_rating'] > 7.5

movies[mask1 & mask2]
# Out:
#                        title_x    imdb_id  \
# 106                      Raazi  tt7098658
# 112    Bhavesh Joshi Superhero  tt6129302
# 169           The Ghazi Attack  tt6299040
# 354              Dangal (film)  tt5074352
# 365     Baby (2015 Hindi film)  tt3848892
# 449          Titli (2014 film)  tt3019620
# 1039          1971 (2007 film)  tt0983990
# 1058  Black Friday (2007 film)  tt0400234
# 1293        Sarkar (2005 film)  tt0432047
# 1361            Lakshya (film)  tt0323013
# 1495            Company (film)  tt0296574
# 1607   Nayak (2001 Hindi film)  tt0291376
#
#                                             poster_path  \
# 106   https://upload.wikimedia.org/wikipedia/en/thum...
# 112   https://upload.wikimedia.org/wikipedia/en/thum...
# 169   https://upload.wikimedia.org/wikipedia/en/thum...
# 354   https://upload.wikimedia.org/wikipedia/en/thum...
# 365   https://upload.wikimedia.org/wikipedia/en/thum...
# 449   https://upload.wikimedia.org/wikipedia/en/thum...
# 1039  https://upload.wikimedia.org/wikipedia/en/thum...
# 1058  https://upload.wikimedia.org/wikipedia/en/5/58...
# 1293  https://upload.wikimedia.org/wikipedia/en/thum...
# 1361  https://upload.wikimedia.org/wikipedia/en/thum...
# 1495  https://upload.wikimedia.org/wikipedia/en/thum...
# 1607  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link  \
# 106                 https://en.wikipedia.org/wiki/Raazi
# 112   https://en.wikipedia.org/wiki/Bhavesh_Joshi_Su...
# 169   https://en.wikipedia.org/wiki/The_Ghazi_Attack...
# 354         https://en.wikipedia.org/wiki/Dangal_(film)
# 365   https://en.wikipedia.org/wiki/Baby_(2015_Hindi...
# 449     https://en.wikipedia.org/wiki/Titli_(2014_film)
# 1039     https://en.wikipedia.org/wiki/1971_(2007_film)
# 1058  https://en.wikipedia.org/wiki/Black_Friday_(20...
# 1293   https://en.wikipedia.org/wiki/Sarkar_(2005_film)
# 1361       https://en.wikipedia.org/wiki/Lakshya_(film)
# 1495       https://en.wikipedia.org/wiki/Company_(film)
# 1607  https://en.wikipedia.org/wiki/Nayak_(2001_Hind...
#
#                       title_y           original_title  is_adult  \
# 106                     Raazi                    Raazi         0
# 112   Bhavesh Joshi Superhero  Bhavesh Joshi Superhero         0
# 169          The Ghazi Attack         The Ghazi Attack         0
# 354                    Dangal                   Dangal         0
# 365                      Baby                     Baby         0
# 449                     Titli                    Titli         0
# 1039                     1971                     1971         0
# 1058             Black Friday             Black Friday         0
# 1293                   Sarkar                   Sarkar         0
# 1361                  Lakshya                  Lakshya         0
# 1495                  Company                  Company         0
# 1607     Nayak: The Real Hero     Nayak: The Real Hero         0
#
#       year_of_release runtime                  genres  imdb_rating  \
# 106              2018     138   Action|Drama|Thriller          7.8
# 112              2018     154            Action|Drama          7.6
# 169              2017     116     Action|Thriller|War          7.6
# 354              2016     161  Action|Biography|Drama          8.4
# 365              2015     159         Action|Thriller          8.0
# 449              2014     116   Action|Drama|Thriller          7.6
# 1039             2007     160        Action|Drama|War          7.9
# 1058             2004     143      Action|Crime|Drama          8.5
# 1293             2005     124      Action|Crime|Drama          7.6
# 1361             2004     186    Action|Drama|Romance          7.9
# 1495             2002     155      Action|Crime|Drama          8.0
# 1607             2001     187   Action|Drama|Thriller          7.8
#
#       imdb_votes                                              story  \
# 106        20289  Hidayat Khan is the son of an Indian freedom f...
# 112         4928  Bhavesh Joshi Superhero is an action film abou...
# 169        10332  In 1971  amid rising tensions between India an...
# 354       131338  Biopic of Mahavir Singh Phogat  who taught wre...
# 365        49426  The country is perpetually under threat from t...
# 449         3677  In the badlands of Delhi's dystopic underbelly...
# 1039        1121  Based on true facts  the film revolves around ...
# 1058       16761  A dramatic presentation of the bomb blasts tha...
# 1293       14694  Meet Subhash Nagre - a wealthy and influential...
# 1361       18777  Karan is a lazy good-for-nothing who lives on ...
# 1495       13474  Mallik is a henchman of Aslam Bhai  a Mumbai u...
# 1607       12522  Employed as a camera-man at a popular televisi...
#
#                                                 summary  \
# 106   A Kashmiri woman agrees to marry a Pakistani a...
# 112   The origin story of Bhavesh Joshi  an Indian s...
# 169   A Pakistani submarine  Ghazi plans to secretly...
# 354   Former wrestler Mahavir Singh Phogat and his t...
# 365   An elite counter-intelligence unit learns of a...
# 449   A Hindi feature film set in the lower depths o...
# 1039  Based on true facts  the film revolves around ...
# 1058  Black Friday is a film about the investigation...
# 1293  The authority of a man  who runs a parallel go...
# 1361  An aimless  jobless  irresponsible grown man j...
# 1495  A small-time gangster named Chandu teams up wi...
# 1607  A man accepts a challenge by the chief ministe...
#
#                                                 tagline  \
# 106                            An incredible true story
# 112            This year| justice will have a new name.
# 169                      The war you did not know about
# 354       You think our girls are any lesser than boys?
# 365           History Is Made By Those Who Give A Damn!
# 449                       Daring| Desireable| Dangerous
# 1039                            Honor the heroes.......
# 1058                The story of the Bombay bomb blasts
# 1293  'There are no Rights and Wrongs. Only Power' -...
# 1361  It took him 24 years and 18000 feet to find hi...
# 1495                           A law & order enterprise
# 1607                                    Fight the power
#
#                                                  actors  \
# 106   Alia Bhatt|Vicky Kaushal|Rajit Kapoor|Shishir ...
# 112   Harshvardhan Kapoor|Priyanshu Painyuli|Ashish ...
# 169   Rana Daggubati|Kay Kay Menon|Atul Kulkarni|Om ...
# 354   Aamir Khan|Fatima Sana Shaikh|Sanya Malhotra|S...
# 365   Akshay Kumar|Danny Denzongpa|Rana Daggubati|Ta...
# 449   Nawazuddin Siddiqui|Niharika Singh|Anil George...
# 1039        Manoj Bajpayee|Ravi Kishan|Deepak Dobriyal|
# 1058  Kay Kay Menon|Pavan Malhotra|Aditya Srivastava...
# 1293  Amitabh Bachchan|Abhishek Bachchan|Kay Kay Men...
# 1361  Hrithik Roshan|Preity Zinta|Amitabh Bachchan|O...
# 1495  Ajay Devgn|Mohanlal|Manisha Koirala|Seema Bisw...
# 1607  Anil Kapoor|Rani Mukerji|Amrish Puri|Johnny Le...
#
#               wins_nominations              release_date Country  \
# 106   21 wins & 26 nominations         11 May 2018 (USA)   India
# 112              2 nominations         1 June 2018 (USA)   India
# 169      1 win & 7 nominations    17 February 2017 (USA)   India
# 354    23 wins & 4 nominations    21 December 2016 (USA)   India
# 365                      1 win   23 January 2015 (India)   India
# 449     4 wins & 5 nominations        20 June 2014 (USA)   India
# 1039                     1 win      9 March 2007 (India)   India
# 1058             3 nominations   9 February 2007 (India)   India
# 1293   2 wins & 10 nominations       1 July 2005 (India)   India
# 1361   4 wins & 10 nominations        18 June 2004 (USA)   India
# 1495   16 wins & 9 nominations     15 April 2002 (India)   India
# 1607             2 nominations  7 September 2001 (India)   India
#
#                lead actor
# 106            Alia Bhatt
# 112   Harshvardhan Kapoor
# 169        Rana Daggubati
# 354            Aamir Khan
# 365          Akshay Kumar
# 449   Nawazuddin Siddiqui
# 1039       Manoj Bajpayee
# 1058        Kay Kay Menon
# 1293     Amitabh Bachchan
# 1361       Hrithik Roshan
# 1495           Ajay Devgn
# 1607          Anil Kapoor

# %%
# write a function that can return the track record of 2 teams against each other

# %% [markdown]
# ### Adding new cols

# %%
# completely new
movies['Country'] = 'India'
movies.head()
# Out:
#               title_x     imdb_id  \
# 11          Gully Boy   tt2395469
# 34      Yeh Hai India   tt5525846
# 37  Article 15 (film)  tt10324144
# 87            Aiyaary   tt6774212
# 96   Raid (2018 film)   tt7363076
#
#                                           poster_path  \
# 11  https://upload.wikimedia.org/wikipedia/en/thum...
# 34  https://upload.wikimedia.org/wikipedia/en/thum...
# 37  https://upload.wikimedia.org/wikipedia/en/thum...
# 87  https://upload.wikimedia.org/wikipedia/en/thum...
# 96  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                           wiki_link        title_y  \
# 11          https://en.wikipedia.org/wiki/Gully_Boy      Gully Boy
# 34      https://en.wikipedia.org/wiki/Yeh_Hai_India  Yeh Hai India
# 37  https://en.wikipedia.org/wiki/Article_15_(film)     Article 15
# 87            https://en.wikipedia.org/wiki/Aiyaary        Aiyaary
# 96   https://en.wikipedia.org/wiki/Raid_(2018_film)           Raid
#
#    original_title  is_adult  year_of_release runtime                  genres  \
# 11      Gully Boy         0             2019     153             Drama|Music
# 34  Yeh Hai India         0             2017     128  Action|Adventure|Drama
# 37     Article 15         0             2019     130             Crime|Drama
# 87        Aiyaary         0             2018     157         Action|Thriller
# 96           Raid         0             2018     122      Action|Crime|Drama
#
#     imdb_rating  imdb_votes  \
# 11          8.2       22440
# 34          5.7         169
# 37          8.3       13417
# 87          5.2        3538
# 96          7.4       13159
#
#                                                 story  \
# 11  Gully Boy is a film about a 22-year-old boy "M...
# 34  Yeh Hai India  follows the story of a 25 years...
# 37  In the rural heartlands of India  an upright p...
# 87  General Gurinder Singh comes with a proposal t...
# 96  Set in the 80s in Uttar Pradesh  India  Raid i...
#
#                                               summary  \
# 11  A coming-of-age story based on the lives of st...
# 34  Yeh Hai India  follows the story of a 25 years...
# 37  In the rural heartlands of India  an upright p...
# 87  After finding out about an illegal arms deal  ...
# 96  A fearless income tax officer raids the mansio...
#
#                                    tagline  \
# 11                       Apna Time Aayega!
# 34                 A Film for Every Indian
# 37  Farq Bahut Kar Liya| Ab Farq Laayenge.
# 87                   The Ultimate Trickery
# 96     Heroes don't always come in uniform
#
#                                                actors        wins_nominations  \
# 11  Ranveer Singh|Alia Bhatt|Siddhant Chaturvedi|V...  6 wins & 3 nominations
# 34   Gavie Chahal|Mohan Agashe|Mohan Joshi|Lom Harsh|   2 wins & 1 nomination
# 37  Ayushmann Khurrana|Nassar|Manoj Pahwa|Kumud Mi...                   1 win
# 87  Sidharth Malhotra|Manoj Bajpayee|Rakul Preet S...            1 nomination
# 96  Ajay Devgn|Saurabh Shukla|Ileana D'Cruz|Amit S...  2 wins & 3 nominations
#
#               release_date Country          lead actor
# 11  14 February 2019 (USA)   India       Ranveer Singh
# 34     24 May 2019 (India)   India        Gavie Chahal
# 37      28 June 2019 (USA)   India  Ayushmann Khurrana
# 87  16 February 2018 (USA)   India   Sidharth Malhotra
# 96   16 March 2018 (India)   India          Ajay Devgn

# %%
# from existing ones
movies.dropna(inplace=True)

# %%
movies['lead actor'] = movies['actors'].str.split('|').apply(lambda x:x[0])
movies.head()
# Out:
#               title_x     imdb_id  \
# 11          Gully Boy   tt2395469
# 34      Yeh Hai India   tt5525846
# 37  Article 15 (film)  tt10324144
# 87            Aiyaary   tt6774212
# 96   Raid (2018 film)   tt7363076
#
#                                           poster_path  \
# 11  https://upload.wikimedia.org/wikipedia/en/thum...
# 34  https://upload.wikimedia.org/wikipedia/en/thum...
# 37  https://upload.wikimedia.org/wikipedia/en/thum...
# 87  https://upload.wikimedia.org/wikipedia/en/thum...
# 96  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                           wiki_link        title_y  \
# 11          https://en.wikipedia.org/wiki/Gully_Boy      Gully Boy
# 34      https://en.wikipedia.org/wiki/Yeh_Hai_India  Yeh Hai India
# 37  https://en.wikipedia.org/wiki/Article_15_(film)     Article 15
# 87            https://en.wikipedia.org/wiki/Aiyaary        Aiyaary
# 96   https://en.wikipedia.org/wiki/Raid_(2018_film)           Raid
#
#    original_title  is_adult  year_of_release runtime                  genres  \
# 11      Gully Boy         0             2019     153             Drama|Music
# 34  Yeh Hai India         0             2017     128  Action|Adventure|Drama
# 37     Article 15         0             2019     130             Crime|Drama
# 87        Aiyaary         0             2018     157         Action|Thriller
# 96           Raid         0             2018     122      Action|Crime|Drama
#
#     imdb_rating  imdb_votes  \
# 11          8.2       22440
# 34          5.7         169
# 37          8.3       13417
# 87          5.2        3538
# 96          7.4       13159
#
#                                                 story  \
# 11  Gully Boy is a film about a 22-year-old boy "M...
# 34  Yeh Hai India  follows the story of a 25 years...
# 37  In the rural heartlands of India  an upright p...
# 87  General Gurinder Singh comes with a proposal t...
# 96  Set in the 80s in Uttar Pradesh  India  Raid i...
#
#                                               summary  \
# 11  A coming-of-age story based on the lives of st...
# 34  Yeh Hai India  follows the story of a 25 years...
# 37  In the rural heartlands of India  an upright p...
# 87  After finding out about an illegal arms deal  ...
# 96  A fearless income tax officer raids the mansio...
#
#                                    tagline  \
# 11                       Apna Time Aayega!
# 34                 A Film for Every Indian
# 37  Farq Bahut Kar Liya| Ab Farq Laayenge.
# 87                   The Ultimate Trickery
# 96     Heroes don't always come in uniform
#
#                                                actors        wins_nominations  \
# 11  Ranveer Singh|Alia Bhatt|Siddhant Chaturvedi|V...  6 wins & 3 nominations
# 34   Gavie Chahal|Mohan Agashe|Mohan Joshi|Lom Harsh|   2 wins & 1 nomination
# 37  Ayushmann Khurrana|Nassar|Manoj Pahwa|Kumud Mi...                   1 win
# 87  Sidharth Malhotra|Manoj Bajpayee|Rakul Preet S...            1 nomination
# 96  Ajay Devgn|Saurabh Shukla|Ileana D'Cruz|Amit S...  2 wins & 3 nominations
#
#               release_date Country          lead actor
# 11  14 February 2019 (USA)   India       Ranveer Singh
# 34     24 May 2019 (India)   India        Gavie Chahal
# 37      28 June 2019 (USA)   India  Ayushmann Khurrana
# 87  16 February 2018 (USA)   India   Sidharth Malhotra
# 96   16 March 2018 (India)   India          Ajay Devgn

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 298 entries, 11 to 1623
# Data columns (total 20 columns):
# title_x             298 non-null object
# imdb_id             298 non-null object
# poster_path         298 non-null object
# wiki_link           298 non-null object
# title_y             298 non-null object
# original_title      298 non-null object
# is_adult            298 non-null int64
# year_of_release     298 non-null int64
# runtime             298 non-null object
# genres              298 non-null object
# imdb_rating         298 non-null float64
# imdb_votes          298 non-null int64
# story               298 non-null object
# summary             298 non-null object
# tagline             298 non-null object
# actors              298 non-null object
# wins_nominations    298 non-null object
# release_date        298 non-null object
# Country             298 non-null object
# lead actor          298 non-null object
# dtypes: float64(1), int64(3), object(16)
# memory usage: 48.9+ KB

# %% [markdown]
# ### Important DataFrame Functions

# %%
# astype
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
# ID                 950 non-null int32
# City               899 non-null object
# Date               950 non-null object
# Season             950 non-null object
# MatchNumber        950 non-null object
# Team1              950 non-null category
# Team2              950 non-null category
# Venue              950 non-null object
# TossWinner         950 non-null object
# TossDecision       950 non-null object
# SuperOver          946 non-null object
# WinningTeam        946 non-null object
# WonBy              950 non-null object
# Margin             932 non-null float64
# method             19 non-null object
# Player_of_Match    946 non-null object
# Team1Players       950 non-null object
# Team2Players       950 non-null object
# Umpire1            950 non-null object
# Umpire2            950 non-null object
# dtypes: category(2), float64(1), int32(1), object(16)
# memory usage: 133.4+ KB

# %%
ipl['ID'] = ipl['ID'].astype('int32')

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
# ID                 950 non-null int32
# City               899 non-null object
# Date               950 non-null object
# Season             950 non-null object
# MatchNumber        950 non-null object
# Team1              950 non-null category
# Team2              950 non-null category
# Venue              950 non-null object
# TossWinner         950 non-null object
# TossDecision       950 non-null object
# SuperOver          946 non-null object
# WinningTeam        946 non-null object
# WonBy              950 non-null object
# Margin             932 non-null float64
# method             19 non-null object
# Player_of_Match    946 non-null object
# Team1Players       950 non-null object
# Team2Players       950 non-null object
# Umpire1            950 non-null object
# Umpire2            950 non-null object
# dtypes: category(2), float64(1), int32(1), object(16)
# memory usage: 133.4+ KB

# %%
# ipl['Season'] = ipl['Season'].astype('category')
ipl['Team1'] = ipl['Team1'].astype('category')
ipl['Team2'] = ipl['Team2'].astype('category')

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
# ID                 950 non-null int32
# City               899 non-null object
# Date               950 non-null object
# Season             950 non-null object
# MatchNumber        950 non-null object
# Team1              950 non-null category
# Team2              950 non-null category
# Venue              950 non-null object
# TossWinner         950 non-null object
# TossDecision       950 non-null object
# SuperOver          946 non-null object
# WinningTeam        946 non-null object
# WonBy              950 non-null object
# Margin             932 non-null float64
# method             19 non-null object
# Player_of_Match    946 non-null object
# Team1Players       950 non-null object
# Team2Players       950 non-null object
# Umpire1            950 non-null object
# Umpire2            950 non-null object
# dtypes: category(2), float64(1), int32(1), object(16)
# memory usage: 133.4+ KB

# %%
# value_counts

# %%
# find which player has won most potm -> in finals and qualifiers

# %%
# Toss decision plot

# %%
# how many matches each team has played

# %%
# sort_values -> ascending -> na_position -> inplace -> multiple cols
