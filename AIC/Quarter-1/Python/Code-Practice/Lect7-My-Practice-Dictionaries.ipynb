# %%
# Dictonaries
# Always start with {}
# Key and Value Pair
# : is used as separator between Key and Value
# , is used to start a new Key Value Pair Value
# In Key Value the Sequerncing / Indexing order does not matter where as it matter in the array
# Key will alwayys be Int or String
# Key name should be unique
# Value can be Int, String, List, Tuple , Dictionary inside a Dictionary

# How to define a Disctionary
data={
    'name':'Zeeshan',  
    'fname':'Asghar',
    'age':42,
     'field':'CS',
      'skills':['SE','AI','ML',"Cloud Computing"],
      0:'Pakistan'}

  # How to get value from a Dictionary
  # Name of Dictionary then key value in []
  # for example data['name']
data
data['name']


# Multiple Values
data2 = {
    'names':['Zeeshan','Usman','Yasir'],
    'fname':['Asghar','Murtaza','Tamkeen'],
    'courses':['CS','Admin','Banking']
}
# Import Pandas Dictionary
import pandas as pd
# use its function DataFrame to get the dataset
df=pd.DataFrame(data2)
df

# Another MEthod to add Dictionary is to declare a empty dictionary

data3={}
data3['name']="Zeeshan Asim"
data3['fname']="Muhammad Asghar Khan"
data3['Course']="Machine Learning"

data3['name']="Usman Murtaza"
data3['fname']="Ghulam Murtaza"
data3['Course']="Business Administration"

data3
# Out:
# {'name': 'Usman Murtaza',
#  'fname': 'Ghulam Murtaza',
#  'Course': 'Business Administration'}

# %%
data4=data3  # Shallow Copy , means both variables points to same memory location
# it means if we change value in one variable it will also reflect in both variable as memory location points to same location

data4=data3.copy()  # This will create a new variable with separate memory location
# N

# Dictionary Functions
# 1. data.clear()    => Will Clear the List

# 2. del data =>  This will del the dictionary variable from the memory

# 3. data2=data.copy()   => To create a new variable with new memory locationb and copy the data from 1st dictionary to other
# Please note that data2=data will not create a new memory Location

# 4. fromkeys
v_keys=['name','fname','course','age','degree']
dict.fromkeys(v_keys)
v_keys

# 5. get()


# 6. items[]


# 7. keys()

# 8 values()
data2 = {
    'names':['Zeeshan','Usman','Yasir'],
    'fname':['Asghar','Murtaza','Tamkeen'],
    'courses':['CS','Admin','Banking']
}

#for v in data2.keys():
#  print(v)


# For Loop
#  print(v)


#9 del function : To delete a key Valuye pair from a Dictionary

# pop function
# popitems function

#10 pop
nm=data2.pop('names')
print(nm)

fnm=data2.pop('fname')
print(fnm)


ag=data2.popitems[]
print(ag)
#pop
# Out:
# ['Zeeshan', 'Usman', 'Yasir']
# ['Asghar', 'Murtaza', 'Tamkeen']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-26fca58f2895> in <module>
#      51
#      52
# ---> 53 ag=data2.popitems[0]
#      54 print(ag)
#      55 #pop
#
# AttributeError: 'dict' object has no attribute 'popitems'

# %%
a,b,c,d=[10,20,30,40]  # TO define multiple variables and assign value to them
print(c)
print(b)


a=len('Pakistan')  # Return Function
print('Pakistan string length is = ', a)

b=print('Hello')  # Non Return Function
print(b)
# Out:
# 30
# 20
# Pakistan string length is =  8
# Hello
# None
