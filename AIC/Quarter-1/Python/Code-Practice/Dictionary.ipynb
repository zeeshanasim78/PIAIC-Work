# %%
# Dictonaries

student = {"name":"Zeeshan", "class":"AI for Everyone", "batch":"37","stud_type":"Online",0:"PCIA2323"}
print(student)
student["email"]="zeeshan@gmail.com"
print(student)
student["email"]="zeeshanasim@gmail.com"
print(student)
rint(student["name"])
print(student[0])
# Out:
# {'name': 'Zeeshan', 'class': 'AI for Everyone', 'batch': '37', 'stud_type': 'Online', 0: 'PCIA2323'}
# {'name': 'Zeeshan', 'class': 'AI for Everyone', 'batch': '37', 'stud_type': 'Online', 0: 'PCIA2323', 'email': 'zeeshan@gmail.com'}
# {'name': 'Zeeshan', 'class': 'AI for Everyone', 'batch': '37', 'stud_type': 'Online', 0: 'PCIA2323', 'email': 'zeeshanasim@gmail.com'}
# Zeeshan
# PCIA2323

# %%
# Python program to illustrate
# enumerate function
l1 = ["eat", "sleep", "repeat"]
s1 = "geek"
  
# creating enumerate objects
obj1 = enumerate(l1)
obj2 = enumerate(s1)
  
print ("Return type:", type(obj1))
print (list(enumerate(l1)))
  
# changing start index to 2 from 0
print (list(enumerate(s1, 2)))
# Out:
# Return type: <class 'enumerate'>
# [(0, 'eat'), (1, 'sleep'), (2, 'repeat')]
# [(2, 'g'), (3, 'e'), (4, 'e'), (5, 'k')]

# %%
D = {1 : 1, 2 : '2', '1' : 1, '2' : 3} 
D['1'] = 2
print(D[D[D[str(D[1])]]])
# Out:
# 3

# %%
D = dict() 
for x in enumerate(range(2)): 
    D[x[0]] = x[1] 
    print(D , x)
    D[x[1]+7] = x[0] 
    print(D)
#print(D)
# Out:
# {0: 0} (0, 0)
# {0: 0, 7: 0}
# {0: 0, 7: 0, 1: 1} (1, 1)
# {0: 0, 7: 0, 1: 1, 8: 1}
