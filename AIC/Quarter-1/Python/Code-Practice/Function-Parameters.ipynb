# %%
def empInfo(name,age,**nationality):
    print("Name : ", name)
    print("Age : ", age)
    for key, value in nationality.items():
        print("%s == %s" % (key, value))
 
 
# To run the function
empInfo("Hassan",56, nationality1='Pakistani')
empInfo("Ali",36, nationality1='Pakistani', nationality2='US')
# Out:
# Name :  Hassan
# Age :  56
# nationality1 == Pakistani
# Name :  Ali
# Age :  36
# nationality1 == Pakistani
# nationality2 == US
