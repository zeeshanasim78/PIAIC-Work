# %%
for num in range(2, 20): 
  if num % 2 == 0:  
    print(" even number", num) 
    continue 
print("odd number", num)
# Out:
#  even number 2
#  even number 4
#  even number 6
#  even number 8
#  even number 10
#  even number 12
#  even number 14
#  even number 16
#  even number 18
# odd number 19
