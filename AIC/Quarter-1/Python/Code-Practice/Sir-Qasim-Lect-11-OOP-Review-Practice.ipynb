# %%
print("Welcome to Class 11")
# Out:
# Welcome to Class 11

# %%
# How to Declare Global Variable
a=7 # Local Variable

def test_function():
  global a  # This will make this variable Global so that it can be accessed outside the function
  a=10
  return a


def test_func():
  return a

print(test_function())
print(test_func())
print(a)
# Out:
# 10
# 10
# 10

# %%
list1 = ["AZ", "YZ", "DG","ZZ"]
print (max(list1))
# Out:
# ZZ
