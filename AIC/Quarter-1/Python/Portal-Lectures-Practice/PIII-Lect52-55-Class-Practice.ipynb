# %%
#PIII-Lect-13
# What is a Class
class Car():
  pass

car1=Car()
print(type(car1))
# Out:
# <class '__main__.Car'>

# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

p1 = Person("John", 36)

print(p1.name)
print(p1.age)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-b105d9c33e9a> in <module>
#       5
#       6 p1 = Person("John", 36)
# ----> 7 p2=Person()
#       8 print(p1.name)
#       9 print(p1.age)
#
# TypeError: __init__() missing 2 required positional arguments: 'name' and 'age'

# %%
class Car:
  ### Car Attributes
    def __init__(self, make, model,year):
      self._make = make
      self._model = model
      self._year=year
    
  # Car Behaviours
    def descriptionCar(self):
      print(f"The Care make is {self._make}")
      print(f"The Care model is {self._model}")
      print(f"The Care year is {self._year}")

    def move(self):
      print(f" {self._make} is moving..")

    def brake(self):
      print(f"{self._make} {self._model} has applied brakes..")

car1=Car("Toyoyta","Yaris", "2020")
car2=Car("Honda","City","2021")

print(car1._make , car1._model)

car1.descriptionCar()
car1.move()

car2.descriptionCar()
car2.brake()
# Out:
# The Care make is Toyoyta
# The Care model is Yaris
# The Care year is 2020
#  Toyoyta is moving..
# The Care make is Honda
# The Care model is City
# The Care year is 2021
# Honda City has applied brakes..
